# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05ae-ui/NASSCOM/blob/main/list_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
fruits = ['apple', 'banana', 'cherry', 'apple']
print("Original list:", fruits)

print("First fruit:", fruits[0])
# Out:
# Original list: ['apple', 'banana', 'cherry', 'apple']
# First fruit: apple

# %%
fruits.remove('banana')
print("After removing banana:", fruits)

# List length
print("Number of fruits:", len(fruits))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_771/3739638526.py in <cell line: 0>()
# ----> 1 fruits.remove('banana')
#       2 print("After removing banana:", fruits)
#       3
#       4 # List length
#       5 print("Number of fruits:", len(fruits))
#
# NameError: name 'fruits' is not defined
