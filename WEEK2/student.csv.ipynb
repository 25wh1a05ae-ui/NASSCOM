# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05ae-ui/NASSCOM/blob/main/WEEK2/student.csv.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("/content/student.csv")
df.head()
# Out:
#    S.no     Roll.no Student name  year  semester   contactno.  cgpa
# 0     1  25wh1a05aa          abc     2         1   1234567890     9
# 1     2  25wh1a05ab          bcd     2         1   2345678901     9
# 2     3  25wh1a05ac          cde     2         1   3456789012     9
# 3     4  25wh1a05ad          def     2         1  45678980132     9
# 4     5  25wh1a05ae          efg     2         1   3245567788     9
