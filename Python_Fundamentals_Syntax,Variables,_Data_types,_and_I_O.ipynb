# %% [markdown]
# <a href="https://colab.research.google.com/github/25wh1a05ae-ui/NASSCOM/blob/main/Python_Fundamentals_Syntax%2CVariables%2C_Data_types%2C_and_I_O.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 🐍 Python Fundamentals: Syntax, Variables, Data Types, and I/O
#
# Welcome to this Python practical! In this notebook, you'll learn:
#
# Python syntax basics
#
# How to declare and use variables
#
# Data types (strings, integers, floats, booleans, lists, dictionaries)
#
# Basic input/output (I/O) operations

# %% [markdown]
# ✍️ Python Syntax Basics

# %%
print("Hello,Python!")
if True:
  print("This is indented correctly.")
else:
  print("This won't run")
# Out:
# Hello,Python!
# This is indented correctly.

# %% [markdown]
# 📦 Variables

# %%
name="Supriya"
age=18
height=5.1

print("Name:",name)
print("Age:",age)
print("Height:",height)

name=123
print("New name:",name)
# Out:
# Name: Supriya
# Age: 18
# Height: 5.1
# New name: 123

# %% [markdown]
# 🔢 Data Types

# %%
a=10
print(type(a))
# Out:
# <class 'int'>

# %%
b=3.123
print(type(b))
# Out:
# <class 'float'>

# %%
c="python"
print(type(c))
# Out:
# <class 'str'>

# %%
d=True
print(type(d))
# Out:
# <class 'bool'>

# %%
e=[1,2,3,4,"five"]
print(type(e),e)
# Out:
# <class 'list'> [1, 2, 3, 4, 'five']

# %%
f={"name":"supriya","age":18}
print(type(f))
# Out:
# <class 'dict'>

# %% [markdown]
# 🖊️ Input and Output Operations

# %%
print("Welcome to Python I/o!")
# Out:
# Welcome to Python I/o!

# %%
user_name =input("Enter user name")
print("Hello,",user_name)
# Out:
# Enter user namesupriya
# Hello, supriya

# %%
user_age=int(input("Enter your age:"))
print("you wil be",user_age+1,"next year")
# Out:
# Enter your age:23
# you wil be 24 next year
